# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
import torch
import random
random.seed(0)
torch.manual_seed(0)

# %%
seed= 42
torch.manual_seed(seed)
print(torch.randperm(5))
torch.manual_seed(seed)
print(torch.randperm(5))
# Out:
# tensor([2, 4, 3, 0, 1])
# tensor([2, 4, 3, 0, 1])

# %%
timestep = 391
dir = "/home/ucaptp0/oasis-rt-surrogate/data/raw_data/raw_data/opacities_data/"

opac_ray_path = os.path.join(dir, "opac_ray-{}.npy".format(timestep))
opac_ext_path = os.path.join(dir, "opac_ext-{}.npy".format(timestep))
opac_path = os.path.join(dir, "opac-{}.npy".format(timestep))

opac_ray = np.load(opac_ray_path)
opac_ext = np.load(opac_ext_path)
opac = np.load(opac_path)

# %%
lev = 49

plt.plot(opac[:, lev])
plt.show()

plt.plot(opac_ray[:, lev])
plt.show()

plt.plot(opac_ext[:, lev])
plt.show()
